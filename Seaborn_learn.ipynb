# %% [markdown]
# <a href="https://colab.research.google.com/github/Anandxz/Machine-Learning/blob/main/Seaborn_learn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Data Visualization

# %%
import numpy as np
import pandas as pd
import io
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df.pd.read_csv('Life Expectancy Data.csv')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-13-79aadb57f06b> in <cell line: 0>()
# ----> 1 df.pd.read_csv('Life Expectancy Data.csv')
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#    6300
#    6301     @final
#
# AttributeError: 'DataFrame' object has no attribute 'pd'

# %%
from google.colab import files

uploaded = files.upload()
import pandas as pd
import io
# Out:
#      <input type="file" id="files-658b3860-35b9-4bc4-b004-e972ebf87d86" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-658b3860-35b9-4bc4-b004-e972ebf87d86">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
  fd = pd.read_csv(io.BytesIO(uploaded["Titanic-Dataset.csv"]))

# %%
fd.shape
# Out:
# (891, 12)

# %%
fd.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
#distplot()-This function will plot a histogram that fits the kernel density estimation(KDE) of the data.

# %% [markdown]
# #Distribution plot

# %%
sns.distplot(fd['Age'])
# Out:
# <Axes: xlabel='Age', ylabel='Density'>

# %%
fd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
sns.histplot(fd["Parch"],kde=False)
plt.show()

# %%
sns.distplot(fd["Age"],hist=False)
plt.show()

# %%
plt.figure(figsize=(9,9))
sns.distplot(fd["Age"])
plt.show()

# %% [markdown]
# # 3. Relational plots

# %%
#The function relplot() is named that way because it is designed to visualize many different statistical relationships

# %%
sns.relplot(x="Age", y="Fare", col="Pclass", hue="Sex", style="Sex",kind="line", data=fd) # scatter can be used instead of "line" plot
plt.show()

# %%
#Scatter plot is the most convenient way to visualize the distribution where each observation is represented in a two-dimensional plot via x and y axis.

# %%
plt.figure(figsize=(9,9))
sns.scatterplot(x="Age", y="Fare", hue="Sex", data=fd)
plt.show()

# %%
plt.figure(figsize=(8,8))
sns.lineplot(x="Age",y="Fare",hue="Sex",style="Sex",data=fd)
# Out:
# <Axes: xlabel='Age', ylabel='Fare'>

# %% [markdown]
# # 4. Categorical Plot

# %%
#barplot

# %%
plt.figure(figsize=(6,6))
sns.barplot(x="Sex", y="Survived", hue="Pclass", data=fd)
plt.show()

# %%
plt.figure(figsize=(8,8))
sns.stripplot(x="Sex", y="Age",hue="Sex", data=fd)
plt.show()

# %%
#swarmplot

#This function positions each point of the scatter plot on the categorical axis and thereby avoids overlapping points:

# %%
plt.figure(figsize=(8,8))
sns.swarmplot(x="Sex", y="Age",hue='Sex', data=fd)
plt.show()

# %%
plt.figure(figsize=(8,8))
sns.boxplot(x="Survived", y="Age",hue="Sex", data=fd)
plt.show()

# %%
plt.subplots(figsize=(8, 8))
sns.pointplot(x="Sex", y="Survived", hue="Pclass", data=fd)
plt.show()

# %% [markdown]
# #5. Regression plots

# %% [markdown]
# lmplot has data as a required parameter and the x and y variables must be specified as strings. This data form is called “long-form” data.

# %%
sns.lmplot(x="Age",y="Fare",data=fd)
plt.show()

# %%
plt.subplots(figsize=(8,8))
sns.regplot(x="Age",y="Fare",data=fd)
plt.show()

# %% [markdown]
# #6. Matrix plots

# %%
sns.heatmap(fd.select_dtypes(include=np.number).corr(),cmap="YlGnBu",annot=True,fmt=".2f")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
